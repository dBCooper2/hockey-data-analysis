# %% [markdown]
# # Accessing Team Data for Hockey Teams
#
# The following Notebook will pull team data from MoneyPuck for the 2020-Current NHL Season. This will be saved in a CSV for the Tableau Dashboard and a Pickle for future Data Analysis

# %%
import pandas as pd
df = pd.read_csv('/Users/dB/Desktop/fall_24/DS-4210/final-proj/data/all_teams.csv')
df.head()
# Out:
#   team  season name      gameId playerTeam opposingTeam home_or_away  \
# 0  NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 1  NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 2  NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 3  NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 4  NYR    2008  NYR  2008020001        NYR          T.B         AWAY
#
#    gameDate    position situation  ...  unblockedShotAttemptsAgainst  \
# 0  20081004  Team Level     other  ...                           1.0
# 1  20081004  Team Level       all  ...                          31.0
# 2  20081004  Team Level      5on5  ...                          20.0
# 3  20081004  Team Level      4on5  ...                           9.0
# 4  20081004  Team Level      5on4  ...                           1.0
#
#    scoreAdjustedUnblockedShotAttemptsAgainst  dZoneGiveawaysAgainst  \
# 0                                      1.000                    0.0
# 1                                     30.369                    5.0
# 2                                     19.369                    3.0
# 3                                      9.000                    1.0
# 4                                      1.000                    1.0
#
#    xGoalsFromxReboundsOfShotsAgainst  xGoalsFromActualReboundsOfShotsAgainst  \
# 0                              0.017                                   0.000
# 1                              0.396                                   0.168
# 2                              0.237                                   0.168
# 3                              0.124                                   0.000
# 4                              0.019                                   0.000
#
#    reboundxGoalsAgainst  totalShotCreditAgainst  \
# 0                 0.000                   0.037
# 1                 0.168                   2.917
# 2                 0.168                   1.862
# 3                 0.000                   0.795
# 4                 0.000                   0.224
#
#    scoreAdjustedTotalShotCreditAgainst  \
# 0                                0.037
# 1                                2.833
# 2                                1.777
# 3                                0.795
# 4                                0.224
#
#    scoreFlurryAdjustedTotalShotCreditAgainst  playoffGame
# 0                                      0.037            0
# 1                                      2.714            0
# 2                                      1.665            0
# 3                                      0.789            0
# 4                                      0.224            0
#
# [5 rows x 111 columns]

# %%
def filter_recent_years(df, year_column, min_year=2019):
    """
    Remove rows from DataFrame where the year is older than the specified minimum year.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame to filter
    year_column : str
        Name of the column containing year values
    min_year : int, optional
        Minimum year to keep (default: 2019)
        
    Returns:
    --------
    pandas.DataFrame
        Filtered DataFrame containing only rows from min_year and newer
        
    Raises:
    -------
    KeyError: If year_column doesn't exist in DataFrame
    ValueError: If year values can't be converted to integers
    
    Runtime Complexity: O(n) where n is the number of rows
    """
    # Verify column exists
    if year_column not in df.columns:
        raise KeyError(f"Year column '{year_column}' not found in DataFrame")
    
    try:
        # Convert year column to numeric if it isn't already
        # This handles various formats like strings, floats, etc.
        years = pd.to_numeric(df[year_column])
        
        # Create year mask and filter DataFrame
        # Using boolean indexing which is very efficient in pandas
        year_mask = years >= min_year
        
        # Return filtered DataFrame
        return df[year_mask].copy()
    
    except ValueError as e:
        raise ValueError(f"Unable to convert values in '{year_column}' to numeric years: {str(e)}")

# %%
#cleaned_df = filter_recent_years(df, 'season', 2023)
cleaned_df.head()
# Out:
#      team  season name      gameId playerTeam opposingTeam home_or_away  \
# 5790  NYR    2023  NYR  2023020010        NYR          BUF         AWAY
# 5791  NYR    2023  NYR  2023020010        NYR          BUF         AWAY
# 5792  NYR    2023  NYR  2023020010        NYR          BUF         AWAY
# 5793  NYR    2023  NYR  2023020010        NYR          BUF         AWAY
# 5794  NYR    2023  NYR  2023020010        NYR          BUF         AWAY
#
#       gameDate    position situation  ...  unblockedShotAttemptsAgainst  \
# 5790  20231012  Team Level     other  ...                           4.0
# 5791  20231012  Team Level       all  ...                          38.0
# 5792  20231012  Team Level      5on5  ...                          24.0
# 5793  20231012  Team Level      4on5  ...                           9.0
# 5794  20231012  Team Level      5on4  ...                           1.0
#
#       scoreAdjustedUnblockedShotAttemptsAgainst  dZoneGiveawaysAgainst  \
# 5790                                      4.000                    0.0
# 5791                                     35.409                    4.0
# 5792                                     21.409                    4.0
# 5793                                      9.000                    0.0
# 5794                                      1.000                    0.0
#
#       xGoalsFromxReboundsOfShotsAgainst  \
# 5790                              0.045
# 5791                              0.424
# 5792                              0.221
# 5793                              0.148
# 5794                              0.009
#
#       xGoalsFromActualReboundsOfShotsAgainst  reboundxGoalsAgainst  \
# 5790                                   0.000                 0.000
# 5791                                   0.273                 0.273
# 5792                                   0.000                 0.000
# 5793                                   0.273                 0.273
# 5794                                   0.000                 0.000
#
#       totalShotCreditAgainst  scoreAdjustedTotalShotCreditAgainst  \
# 5790                   0.174                                0.174
# 5791                   2.407                                2.275
# 5792                   1.312                                1.181
# 5793                   0.793                                0.793
# 5794                   0.128                                0.128
#
#       scoreFlurryAdjustedTotalShotCreditAgainst  playoffGame
# 5790                                      0.155            0
# 5791                                      2.225            0
# 5792                                      1.173            0
# 5793                                      0.769            0
# 5794                                      0.128            0
#
# [5 rows x 111 columns]

# %%
cleaned_df.to_csv('/Users/dB/Desktop/fall_24/DS-4210/final-proj/data/teams.csv')
cleaned_df.to_pickle('/Users/dB/Desktop/fall_24/DS-4210/final-proj/data/teams.pkl')

# %%
# save the complete dataset to pkl
df.to_pickle('/Users/dB/Desktop/fall_24/DS-4210/final-proj/data/complete_teams_dataset.pkl')
